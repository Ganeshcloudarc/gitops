# %%
# https://hratliff.com/posts/2019/02/curvature-of-three-points/
'''
Curvature, circumradius, and circumcenter functions
written by Hunter Ratliff on 2019-02-03
'''

def curvature(x_data,y_data):
    '''
    Calculates curvature for all interior points
    on a curve whose coordinates are provided
    Input:
        - x_data: list of n x-coordinates
        - y_data: list of n y-coordinates
    Output:
        - curvature: list of n-2 curvature values
    '''
    curvature = []
    for i in range(1,len(x_data)-1):
        R = circumradius(x_data[i-1:i+2],y_data[i-1:i+2])
        if ( R == 0 ):
            print('Failed: points are either collinear or not distinct')
            return 0
        curvature.append(1/R)
    return curvature

def circumradius(xvals,yvals):
    '''
    Calculates the circumradius for three 2D points
    '''
    x1, x2, x3, y1, y2, y3 = xvals[0], xvals[1], xvals[2], yvals[0], yvals[1], yvals[2]
    den = 2*((x2-x1)*(y3-y2)-(y2-y1)*(x3-x2))
    num = ( (((x2-x1)**2) + ((y2-y1)**2)) * (((x3-x2)**2)+((y3-y2)**2)) * (((x1-x3)**2)+((y1-y3)**2)) )**(0.5)
    if ( den == 0 ):
        print('Failed: points are either collinear or not distinct')
        return 0
    R = abs(num/den)
    return R

def circumcenter(xvals,yvals):
    '''
    Calculates the circumcenter for three 2D points
    '''
    x1, x2, x3, y1, y2, y3 = xvals[0], xvals[1], xvals[2], yvals[0], yvals[1], yvals[2]
    A = 0.5*((x2-x1)*(y3-y2)-(y2-y1)*(x3-x2))
    if ( A == 0 ):
        print('Failed: points are either collinear or not distinct')
        return 0
    xnum = ((y3 - y1)*(y2 - y1)*(y3 - y2)) - ((x2**2 - x1**2)*(y3 - y2)) + ((x3**2 - x2**2)*(y2 - y1))
    x = xnum/(-4*A)
    y =  (-1*(x2 - x1)/(y2 - y1))*(x-0.5*(x1 + x2)) + 0.5*(y1 + y2)
    return x, y

# test values
x = [0,0.8,2.8,5, 10, 3]
y = [0,1.6,-0.4,5, 3,6]

print(curvature(x,y))
print(circumradius(x[0:3],y[0:3]))
print(circumcenter(x[0:3],y[0:3]))
# Out:
# [0.6708203932499369, 0.34111255618506214, 0.2511750846673402, 0.0218088114494371]
# 1.4907119849998598
# (1.4666666666666668, 0.2666666666666666)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
# plt.style.use('_mpl-gallery

# %%
import numpy as np

import matplotlib.pyplot as plt
x = np.random.rand(10) * 10
y = np.random.rand(10)* 10
figure, axes = plt.subplots()
points = plt.scatter(x,y)

for i in range(1,len(x)-2):
    print("x[i-1:i+2]", x[i-1:i+2])
    print("y[i-1:i+2]", y[i-1:i+2])
    x_c,y_c= circumcenter(x[i-1:i+2],y[i-1:i+2])
#     print()
    r = circumradius(x[0:3],y[0:3])
    print("r", r)
    points = plt.scatter(x_c,y_c)

    Drawing_uncolored_circle = plt.Circle( (x_c, y_c ),
                                      r*2 ,
                                      fill = False )
#     axes.set_aspect( 1 )

    axes.add_artist( Drawing_uncolored_circle )

plt.title( 'Circle' )
plt.show()
# Out:
# x[i-1:i+2] [2.1372831  8.79801852 8.97582763]
# y[i-1:i+2] [9.94818374 5.08141079 2.33137252]
# r 6.667001904003163
# x[i-1:i+2] [8.79801852 8.97582763 1.78273116]
# y[i-1:i+2] [5.08141079 2.33137252 1.79551712]
# r 6.667001904003163
# x[i-1:i+2] [8.97582763 1.78273116 2.30437744]
# y[i-1:i+2] [2.33137252 1.79551712 5.64124673]
# r 6.667001904003163
# x[i-1:i+2] [1.78273116 2.30437744 9.34182399]
# y[i-1:i+2] [1.79551712 5.64124673 9.69469923]
# r 6.667001904003163
# x[i-1:i+2] [2.30437744 9.34182399 5.01513393]
# y[i-1:i+2] [5.64124673 9.69469923 7.3579577 ]
# r 6.667001904003163
# x[i-1:i+2] [9.34182399 5.01513393 0.82117123]
# y[i-1:i+2] [9.69469923 7.3579577  3.37042192]
# r 6.667001904003163
# x[i-1:i+2] [5.01513393 0.82117123 1.76005814]
# y[i-1:i+2] [7.3579577  3.37042192 6.60996312]
# r 6.667001904003163

# %%
x = np.random.rand(10) * 10
y = np.random.rand(10)* 10

# %%
from pylab import *
figure(figsize=(8,8))
ax=subplot(aspect='equal')

#plot one circle (the biggest one on bottom-right)
circles(1, 0, 0.5, 'r', alpha=0.2, lw=5, edgecolor='b', transform=ax.transAxes)

#plot a set of circles (circles in diagonal)
a=arange(11)
out = circles(a, a, a*0.2, c=a, alpha=0.5, edgecolor='none')
colorbar(out)

xlim(0,10)
ylim(0,10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16174/78020678.py in <module>
#       4
#       5 #plot one circle (the biggest one on bottom-right)
# ----> 6 circles(1, 0, 0.5, 'r', alpha=0.2, lw=5, edgecolor='b', transform=ax.transAxes)
#       7
#       8 #plot a set of circles (circles in diagonal)
#
# NameError: name 'circles' is not defined
